# %% [markdown]
# # Regresión Polinómica-Polynomial-Regression(for simple exercises)

# %% [markdown]
# ## Imporamos nuestras librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importamos nuestro Conjunto de Datos (Dataset)

# %%
dataset = pd.read_csv('polynomial-regression.csv')
X = dataset.iloc[:, 0:1].values
y = dataset.iloc[:, -1].values
dataset
# Out:
#     araba_fiyat  araba_max_hiz
# 0            60            180
# 1            70            180
# 2            80            200
# 3           100            200
# 4           120            200
# 5           150            220
# 6           200            240
# 7           250            240
# 8           300            300
# 9           400            350
# 10          500            350
# 11          750            360
# 12         1000            365
# 13         2000            365
# 14         3000            365

# %% [markdown]
# ## Entrenamiento del modelo de regresión lineal simple con el conjunto de datos

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Entrenamiento del modelo de regresión polinomial en todo el conjunto de datos

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualización de los resultados del conjunto de entrenamiento

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Ejercicio simple (Linear Regression)')
plt.xlabel('araba_fiyat')
plt.ylabel('araba_max_hiz')
plt.show()

# %% [markdown]
# ## Visualización de los resultados del conjunto de entrenamiento

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Ejercicio Simple (Linear Regression)')
plt.xlabel('araba_fiyat')
plt.ylabel('araba_max_hiz')
plt.show()

# %% [markdown]
# ## Visualización de los resultados de la regresión polinomial (para una resolución más alta y una curva más suave)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Ejercicio Simple (Linear Regression)')
plt.xlabel('araba_fiyat')
plt.ylabel('araba_max_hiz')
plt.show()

# %% [markdown]
# ## Predicción de un nuevo resultado con regresión lineal

# %%
lin_reg.predict([[3000]])
# Out:
# array([426.90638163])

# %% [markdown]
# ## Predicción de un nuevo resultado con regresión polinómica

# %%
lin_reg_2.predict(poly_reg.fit_transform([[3000]]))
# Out:
# array([365.08790796])
